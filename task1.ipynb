# %% [markdown]
# <a href="https://colab.research.google.com/github/angeltaneja/developers-task/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PROJECT
# Personal Introduction Program

# Ask for user's information
name = input("What is your name? ")
age = input("How old are you? ")
hobby = input("What is your favorite hobby? ")

# Display the welcome message
print("\n Personal Introduction")
print(f"Hello, {name}! Nice to meet you ")
print(f"You are {age} years old and enjoy {hobby}.")
print("That sounds awesome! Welcome aboard!")
# Out:
# What is your name? angel
# How old are you? 21
# What is your favorite hobby? dancing
#
#  Personal Introduction
# Hello, angel! Nice to meet you
# You are 21 years old and enjoy dancing.
# That sounds awesome! Welcome aboard!

# %%
# My first Python program
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Personal Information
name = "Angel"
age = 21
city = "saharanpur"

# %%
# Basic math practice
addition = 5 + 3
subtraction = 10 - 4
multiplication = 7 * 6
division = 20 / 5

print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
# Out:
# Addition: 8
# Subtraction: 6
# Multiplication: 42
# Division: 4.0

# %%
# List of favorite foods
favorite_foods = ["Pizza", "Sushi", "Burgers", "Ice Cream"]

# Access items in the list
print("My favorite food is:", favorite_foods[0])
print("Here’s my full list of favorites:", favorite_foods)
# Out:
# My favorite food is: Pizza
# Here’s my full list of favorites: ['Pizza', 'Sushi', 'Burgers', 'Ice Cream']

# %%
# Simple Bio-data Program

# Asking for user input
name = input("Enter your name: ")
age = input("Enter your age: ")
city = input("Enter your city: ")

# Displaying bio-data
print("\n--- Bio-Data ---")
print(f"Name: {name}")
print(f"Age: {age}")
print(f"City: {city}")
print("Welcome to Python programming! ")
# Out:
# Enter your name: angel
# Enter your age: 21
# Enter your city: saharanpur
#
# --- Bio-Data ---
# Name: angel
# Age: 21
# City: saharanpur
# Welcome to Python programming!
